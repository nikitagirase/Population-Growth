# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
countries_df = pd.read_csv('countries.csv')

countries = countries_df

countries.head(3)
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083

# %%
c_52 = countries.loc[countries['year'] == 1952]
c_52.head()
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 12      Albania  1952     1282697
# 24      Algeria  1952     9279525
# 36       Angola  1952     4232095
# 48    Argentina  1952    17876956

# %%
c_07 = countries.loc[countries['year'] == 2007]
c_07.head()
# Out:
#         country  year  population
# 11  Afghanistan  2007    31889923
# 23      Albania  2007     3600523
# 35      Algeria  2007    33333216
# 47       Angola  2007    12420476
# 59    Argentina  2007    40301927

# %%
type(c_52)
# Out:
# pandas.core.frame.DataFrame

# %%
c_merge = c_52.merge(c_07, left_on='country', right_on='country')

# %%
c_merge.head()
# Out:
#        country  year_x  population_x  year_y  population_y
# 0  Afghanistan    1952       8425333    2007      31889923
# 1      Albania    1952       1282697    2007       3600523
# 2      Algeria    1952       9279525    2007      33333216
# 3       Angola    1952       4232095    2007      12420476
# 4    Argentina    1952      17876956    2007      40301927

# %%
c_merge.drop(['year_x', 'year_y'], axis=1)
# Out:
#                 country  population_x  population_y
# 0           Afghanistan       8425333      31889923
# 1               Albania       1282697       3600523
# 2               Algeria       9279525      33333216
# 3                Angola       4232095      12420476
# 4             Argentina      17876956      40301927
# ..                  ...           ...           ...
# 137             Vietnam      26246839      85262356
# 138  West Bank and Gaza       1030585       4018332
# 139         Yemen, Rep.       4963829      22211743
# 140              Zambia       2672000      11746035
# 141            Zimbabwe       3080907      12311143
#
# [142 rows x 3 columns]

# %%
c_merge.head()
# Out:
#        country  year_x  population_x  year_y  population_y
# 0  Afghanistan    1952       8425333    2007      31889923
# 1      Albania    1952       1282697    2007       3600523
# 2      Algeria    1952       9279525    2007      33333216
# 3       Angola    1952       4232095    2007      12420476
# 4    Argentina    1952      17876956    2007      40301927

# %%
c_merge['population_growth'] = c_merge['population_y'] - c_merge['population_x']

# %%
c_merge.head()
# Out:
#        country  year_x  population_x  year_y  population_y  population_growth
# 0  Afghanistan    1952       8425333    2007      31889923           23464590
# 1      Albania    1952       1282697    2007       3600523            2317826
# 2      Algeria    1952       9279525    2007      33333216           24053691
# 3       Angola    1952       4232095    2007      12420476            8188381
# 4    Argentina    1952      17876956    2007      40301927           22424971

# %%
31889923 - 8425333 #test the math
# Out:
# 23464590

# %%
c_merge.shape, type(c_merge)
# Out:
# ((142, 6), pandas.core.frame.DataFrame)

# %%
c_merge = c_merge.sort_values('population_growth', ascending=False).head(10)

# %%
c_merge.head(10)
# Out:
#            country  year_x  population_x  year_y  population_y  \
# 24           China    1952     556263527    2007    1318683096
# 58           India    1952     372000000    2007    1110396331
# 134  United States    1952     157553000    2007     301139947
# 59       Indonesia    1952      82052000    2007     223547000
# 14          Brazil    1952      56602560    2007     190010647
# 97        Pakistan    1952      41346560    2007     169270617
# 8       Bangladesh    1952      46886859    2007     150448339
# 94         Nigeria    1952      33119096    2007     135031164
# 82          Mexico    1952      30144317    2007     108700891
# 101    Philippines    1952      22438691    2007      91077287
#
#      population_growth
# 24           762419569
# 58           738396331
# 134          143586947
# 59           141495000
# 14           133408087
# 97           127924057
# 8            103561480
# 94           101912068
# 82            78556574
# 101           68638596

# %%
c_merge = c_merge.reset_index()

# %%
c_merge.head(10)
# Out:
#    index        country  year_x  population_x  year_y  population_y  \
# 0     24          China    1952     556263527    2007    1318683096
# 1     58          India    1952     372000000    2007    1110396331
# 2    134  United States    1952     157553000    2007     301139947
# 3     59      Indonesia    1952      82052000    2007     223547000
# 4     14         Brazil    1952      56602560    2007     190010647
# 5     97       Pakistan    1952      41346560    2007     169270617
# 6      8     Bangladesh    1952      46886859    2007     150448339
# 7     94        Nigeria    1952      33119096    2007     135031164
# 8     82         Mexico    1952      30144317    2007     108700891
# 9    101    Philippines    1952      22438691    2007      91077287
#
#    population_growth
# 0          762419569
# 1          738396331
# 2          143586947
# 3          141495000
# 4          133408087
# 5          127924057
# 6          103561480
# 7          101912068
# 8           78556574
# 9           68638596

# %%
c_merge.shape
# Out:
# (10, 7)

# %%
c_merge = c_merge.drop(['index'], axis=1)

# %%
c_merge.shape
# Out:
# (10, 6)

# %%
c_merge
# Out:
#          country  year_x  population_x  year_y  population_y  \
# 0          China    1952     556263527    2007    1318683096
# 1          India    1952     372000000    2007    1110396331
# 2  United States    1952     157553000    2007     301139947
# 3      Indonesia    1952      82052000    2007     223547000
# 4         Brazil    1952      56602560    2007     190010647
# 5       Pakistan    1952      41346560    2007     169270617
# 6     Bangladesh    1952      46886859    2007     150448339
# 7        Nigeria    1952      33119096    2007     135031164
# 8         Mexico    1952      30144317    2007     108700891
# 9    Philippines    1952      22438691    2007      91077287
#
#    population_growth
# 0          762419569
# 1          738396331
# 2          143586947
# 3          141495000
# 4          133408087
# 5          127924057
# 6          103561480
# 7          101912068
# 8           78556574
# 9           68638596

# %%
names = ['China', 'India', 'United States', 'Indonesia', 'Brazil', 'Pakistan', 'Bangledesh', 'Nigeria', 'Mexico', 'Philippines']
pop_grow = (c_merge['population_growth'] / 10**6)

plt.figure(figsize=(15,9))
plt.bar(names,pop_grow,width=0.6)
plt.xlabel('Country')
plt.ylabel('Population Growth (Millions)')
plt.title('Top 10 Countries w/the Biggest Population Growth from 1952 to 2007')
plt.xticks(rotation=45)

# zip joins x and y coordinates in pairs
for x,y in zip(names,pop_grow):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

plt.show()
